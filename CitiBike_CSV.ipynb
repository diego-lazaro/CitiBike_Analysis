# %%
# Dependencies and Setup
import pandas as pd

# Read Purchasing File and store into Pandas data frame
jan = pd.read_csv("./Resources/JC-201912-citibike-tripdata.csv")
feb = pd.read_csv("./Resources/JC-202001-citibike-tripdata.csv")
mar = pd.read_csv("./Resources/JC-202002-citibike-tripdata.csv")
apr = pd.read_csv("./Resources/JC-202003-citibike-tripdata.csv")
may = pd.read_csv("./Resources/JC-202004-citibike-tripdata.csv")
jun = pd.read_csv("./Resources/JC-202005-citibike-tripdata.csv")
jul = pd.read_csv("./Resources/JC-202006-citibike-tripdata.csv")
aug = pd.read_csv("./Resources/JC-202007-citibike-tripdata.csv")
sep = pd.read_csv("./Resources/JC-202008-citibike-tripdata.csv")
oct = pd.read_csv("./Resources/JC-202009-citibike-tripdata.csv")
nov = pd.read_csv("./Resources/JC-202010-citibike-tripdata.csv")
dec = pd.read_csv("./Resources/JC-202011-citibike-tripdata.csv")

# %%
# Create a DataFrame and rename columns
frames = [jan, feb, mar, apr, may, jun, jul, aug, sep, oct, nov, dec]
result = pd.concat(frames)

# %%
# Print results
result
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1               416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2               294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3                97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4               286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
# ...             ...                       ...                       ...
# 21270           849  2020-11-30 23:08:40.1870  2020-11-30 23:22:50.0830
# 21271           370  2020-11-30 23:09:27.0180  2020-11-30 23:15:37.3330
# 21272           341  2020-11-30 23:37:53.0580  2020-11-30 23:43:34.1200
# 21273          5272  2020-11-30 23:49:31.8650  2020-12-01 01:17:24.2540
# 21274           222  2020-11-30 23:56:52.8310  2020-12-01 00:00:34.8660
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Convert DataFrame into CSV file
result.to_csv("Citibike_2020.csv", index=False)
